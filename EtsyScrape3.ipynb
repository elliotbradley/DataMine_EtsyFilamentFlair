# %%
#Initializing For Code
from urllib.request import urlopen
import csv
url = "https://www.etsy.com/shop/FilamentFlair"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")

#Preparing for Loop
current_html = html

#Page Total
pageT_html = html
pageT_html = pageT_html[pageT_html.find('<div class="display-inline-block vertical-align-middle">(')+len('<div class="display-inline-block vertical-align-middle">('):]
pageT_rev = int(pageT_html[:pageT_html.find(')')])
pageT = pageT_rev//10

#GET LOOP NUMBER
Iterations = html.count('<p class="shop2-review-attribution">')

#STORE INFO IN CSV
with open('DataSheet2.csv', 'w', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['Name','Date','Rating','Comments','Product'])
    
    for page in range(pageT+1):
        for i in range(Iterations):
            # MOVE HTML TO NAME
            start_index = current_html.find('<p class="shop2-review-attribution">')+ len('<p class="shop2-review-attribution">')
            current_html = current_html[start_index:]

            #COLLECT NAME
            start_index = current_html.find('>')+1
            end_index = current_html.find('</a>')
            Name = current_html[start_index:end_index]

            #MOVE HTML TO DATE
            current_html = current_html[current_html.find('on ')+len('on '):]

            #COLLECT DATE
            start_index = 0
            end_index = current_html.find('\n')
            Date = current_html[start_index:end_index]

            #MOVE HTML TO RATING
            current_html = current_html[current_html.find('span class="stars-svg "'):]
            current_html = current_html[current_html.find('name="rating" value=')+len('name="rating" value='):]

            #COLLECT RATING
            start_index = 1
            end_index = current_html.find('" />')
            Rating = current_html[start_index:end_index]

            #MOVE HTML TO COMMENTS
            current_html = current_html[current_html.find('<p class="prose break-word m-xs-0">')+len('<p class="prose break-word m-xs-0">'):]

            #COLLECT COMMENTS
            start_index = 0
            end_index = current_html.find('</p>')
            Comments = current_html[start_index:end_index]

            #MOVE HTML TO PRODUCT BOUGHT
            current_html = current_html[current_html.find('<div class="flag-body hide-xs hide-sm">')+len('<div class="flag-body hide-xs hide-sm">\n                    <p>'):]

            #COLLECT PRODUCT BOUGHT
            start_index = 0
            end_index = current_html.find('</p>')
            Product = current_html[start_index:end_index]

            #WRITE ROW INTO CSV
            writer.writerow([Name,Date,Rating,Comments,Product])
        if page != pageT:
            #Reset url
            print(page)
            url = "https://www.etsy.com/shop/FilamentFlair?ref=pagination&amp;page=2"
            #https://www.etsy.com/shop/FilamentFlair?ref=pagination&amp;page=2
            #
            page = urlopen(url)
            html_bytes = page.read()
            html = html_bytes.decode("utf-8")

            #Preparing for Loop
            current_html = html
            
            #GET LOOP NUMBER
            Iterations = html.count('<p class="shop2-review-attribution">')
        else:
            continue
# Out:
# 0
# 1
# 2

# %%
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="en-US"
#     xmlns:og="http://ogp.me/ns#"
#     xmlns:fb="https://www.facebook.com/2008/fbml"
#
#
# >
#     <head>
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <meta name="pinterest" content="nosearch">
#
#         <meta name="csrf_nonce" content="3:1647831940:qxulBUBR4YYfoTeP77fogG3tWyzC:712407917f97b934821bc5ee2cc8981990ad86c4ec4b4480651feac10b7bcfcc">
#         <meta name="uaid_nonce" content="3:1647831940:lDTL5aVy3PC7Oc1omOClLveaWEQq:0d5064931fd8dca2736c449c0653ab3db99b89fabdd53d665d0e5339873d539a">
#
#         <meta property="fb:app_id" content="89186614300">
#
#         <meta name="css_dist_path" content="/ac/primary/css/" />
#         <meta name="dist" content="202203181647645085" />
#
# ...

# %%
#Initializing For Code
from urllib.request import urlopen
import csv
url = "https://www.etsy.com/shop/FilamentFlair?ref=pagination&page=3"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")

# %%
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="en-US"
#     xmlns:og="http://ogp.me/ns#"
#     xmlns:fb="https://www.facebook.com/2008/fbml"
#
#
# >
#     <head>
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <meta name="pinterest" content="nosearch">
#
#         <meta name="csrf_nonce" content="3:1647833160:m0jOMlRvn-lh74mvq9ZV2bFDoetE:dc80889b11a3d553aece19b32ff12d256edfc743c23c8042b27c1a70e21887a0">
#         <meta name="uaid_nonce" content="3:1647833160:WD53a9F1Nyf4bo-2cbl1l-VxJ_-U:bec930e073b892b07853acd4b61bc0afbc0d5148d6240c33f190ca98e9f3c0f8">
#
#         <meta property="fb:app_id" content="89186614300">
#
#         <meta name="css_dist_path" content="/ac/primary/css/" />
#         <meta name="dist" content="202203181647645085" />
#
# ...

# %%
<div class="display-inline-block vertical-align-middle">(

# %%
pageT_html = html
pageT_html = pageT_html[pageT_html.find('<div class="display-inline-block vertical-align-middle">(')+len('<div class="display-inline-block vertical-align-middle">('):]
pageT_rev = int(pageT_html[:pageT_html.find(')')])
pageT = pageT_rev//10
pageT
# Out:
# 3

# %%
for page in range(pageT+1):
    if page == pageT:
        continue
    else:
        print(page+1)
# Out:
# 1
# 2
# 3
